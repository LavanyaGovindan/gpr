# %%
import pandas as pd
import ipywidgets as widgets
from IPython.display import display
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib nbagg

# %%
df1 = pd.read_csv('F:/Lavanya/b-scan/Data/Example/cylinder_Bscan_2D_merged1.csv',skiprows=7, header=None)
df2 = []
row, colm = df1.shape

for x in np.arange(0,colm):
    df2.append(np.mean(df1[x]))
               
df2 = np.asarray(df2)
x = np.subtract(df1,df2)
fig,(ax1,ax2) = plt.subplots(1,2)
im1 = ax1.imshow(np.transpose(x),cmap = 'jet' , aspect='auto')
plt.colorbar(im1)

im2 = ax2.imshow(np.transpose(df1),cmap = 'jet' , aspect='auto')
plt.colorbar(im2)

# %%
row
# Out:
# 59

# %%
img = np.transpose(df1)

# %%
type(img[6])
# Out:
# pandas.core.series.Series
